# %%
import pandas as pd
from dateutil.relativedelta import relativedelta
import numpy as np

# %%
leagues = []
with open('fbr_links.txt', 'r') as fbr_links_file:
    for line in fbr_links_file:
        leagues.append(line.split(',')[0])
print(leagues)
# Out:
# ['English Premier League', 'Spanish La Liga', 'French Ligue 1', 'German Bundesliga', 'Italian Serie A']

# %%
tm_data_df = None
for league in leagues:
    act_df = pd.read_csv(f'{league}/tm_data.csv')
    act_df['League'] = league
    tm_data_df = pd.concat([tm_data_df, act_df])
tm_data_df
# Out:
#                  Player            Role             Team         Birth  \
# 0               Ederson      Goalkeeper  Manchester City  Aug 17, 1993
# 1         Stefan Ortega      Goalkeeper  Manchester City   Nov 6, 1992
# 2          Scott Carson      Goalkeeper  Manchester City   Sep 3, 1985
# 3            Rúben Dias     Centre-Back  Manchester City  May 14, 1997
# 4        Josko Gvardiol     Centre-Back  Manchester City  Jan 23, 2002
# ..                  ...             ...              ...           ...
# 544       Elayis Tavsan    Right Winger    Hellas Verona  Apr 30, 2001
# 545     Karol Świderski  Centre-Forward    Hellas Verona  Jan 23, 1997
# 546        Thomas Henry  Centre-Forward    Hellas Verona  Sep 20, 1994
# 547  Federico Bonazzoli  Centre-Forward    Hellas Verona  May 21, 1997
# 548   Juan Manuel Cruz   Centre-Forward    Hellas Verona  Jul 19, 1999
#
#        Value                  League
# 0    €40.00m  English Premier League
# 1     €9.00m  English Premier League
# 2      €200k  English Premier League
# 3    €80.00m  English Premier League
# 4    €75.00m  English Premier League
# ..       ...                     ...
# 544   €1.00m         Italian Serie A
# 545   €6.00m         Italian Serie A
# 546   €3.50m         Italian Serie A
# 547   €3.00m         Italian Serie A
# 548    €450k         Italian Serie A
#
# [2560 rows x 6 columns]

# %%
tm_data_df['Role'].unique()
# Out:
# array(['Goalkeeper', 'Centre-Back', 'Left-Back', 'Right-Back',
#        'Defensive Midfield', 'Central Midfield', 'Attacking Midfield',
#        'Left Winger', 'Right Winger', 'Second Striker', 'Centre-Forward',
#        'Left Midfield', 'Right Midfield'], dtype=object)

# %%
fbr_data_df = None
for league in leagues:
    fbr_data_df = pd.concat([fbr_data_df, pd.read_csv(f'{league}/fbr_data.csv')])
fbr_data_df
# Out:
#                 Player   Role Position   Foot Height Weight  \
# 0       William Saliba     DF     (CB,  Right  193cm   76kg
# 1          Declan Rice  DF-MF  (CM-DM)  Right  185cm   77kg
# 2          Bukayo Saka  FW-MF     (AM)   Left  178cm   64kg
# 3            Ben White     DF  (CB-FB,  Right  182cm   73kg
# 4    Gabriel Magalhães     DF     (CB,   Left  190cm   78kg
# ..                 ...    ...      ...    ...    ...    ...
# 410         Iron Gomis     MF  (AM-CM)  Right  182cm   78kg
# 411    Emanuel Vignato  FW-MF      NaN  Right  175cm   68kg
# 412  Vincenzo Fiorillo     GK      NaN   Left  190cm   74kg
# 413                NaN    NaN      NaN    NaN    NaN    NaN
# 414                NaN    NaN      NaN    NaN    NaN    NaN
#
#                  Birth Nationality         Club      Wage  ...  2023-2024  \
# 0       March 24, 2001      France      Arsenal  222300.0  ...        NaN
# 1     January 14, 1999     England      Arsenal  280800.0  ...        NaN
# 2    September 5, 2001     England      Arsenal  228150.0  ...        NaN
# 3      October 8, 1997     England      Arsenal  175500.0  ...        NaN
# 4    December 19, 1997      Brazil      Arsenal  117000.0  ...        NaN
# ..                 ...         ...          ...       ...  ...        ...
# 410   November 8, 1999      France  Salernitana     5,385  ...        NaN
# 411    August 24, 2000       Italy  Salernitana    14,231  ...        NaN
# 412   January 13, 1990       Italy  Salernitana     9,615  ...        NaN
# 413                NaN         NaN          NaN       NaN  ...        NaN
# 414                NaN         NaN          NaN       NaN  ...        NaN
#
#      4Seasons*  2019-2020  2024-2025  2025-2026  5Seasons*  6Seasons*  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 410        NaN        NaN        NaN        NaN        NaN        NaN
# 411        NaN        NaN        NaN        NaN        NaN        NaN
# 412        NaN        NaN        NaN        NaN        NaN        NaN
# 413        NaN        NaN        NaN        NaN        NaN        NaN
# 414        NaN        NaN        NaN        NaN        NaN        NaN
#
#      3Seasons* 1Seasons*  2Seasons*
# 0          NaN       NaN        NaN
# 1          NaN       NaN        NaN
# 2          NaN       NaN        NaN
# 3          NaN       NaN        NaN
# 4          NaN       NaN        NaN
# ..         ...       ...        ...
# 410        NaN       NaN        NaN
# 411        NaN       NaN        NaN
# 412        NaN       NaN        NaN
# 413        NaN       NaN        NaN
# 414        NaN       NaN        NaN
#
# [1858 rows x 56 columns]

# %%
fbr_data_df.drop_duplicates(subset='Player', keep='first', inplace=True)

# %%
fbr_data_df = fbr_data_df.drop(['Position', 'Role'], axis=1)

# %%
fbr_data_df['Height'] = fbr_data_df['Height'].replace('Born:', np.nan)
fbr_data_df.dropna(subset=['Height'], inplace=True)
len(fbr_data_df)
# Out:
# 1654

# %%
fbr_data_df['Height'] = fbr_data_df['Height'].str.replace('cm', '').astype(float)
fbr_data_df['Height'].unique()
# Out:
# array([193., 185., 178., 182., 190., 186., 180., 179., 175., 177., 172.,
#        195., 169., 174., 187., 188., 197., 170., 173., 191., 181., 183.,
#        192., 189., 198., 194., 176., 184., 168., 196., 171., 166., 167.,
#        164., 165., 199., 202., 201.])

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
fbr_data_df = fbr_data_df[~fbr_data_df['Weight'].isin(months)]
len(fbr_data_df)
# Out:
# 1654

# %%
fbr_data_df['Weight'] = fbr_data_df['Weight'].apply(lambda x: None if str(x).startswith('(') else x)

# %%
fbr_data_df['Weight'] = fbr_data_df['Weight'].str.replace('kg', '').astype(float)
fbr_data_df['Weight'].unique()
# Out:
# array([76., 77., 64., 73., 78., 81., 74., 68., 60., 72., 66., 79., 71.,
#        91., 83., 63., 69., 87., 67., nan, 88., 82., 84., 86., 62., 70.,
#        92., 59., 89., 97., 75., 58., 54., 52., 94., 55., 53., 57., 49.,
#        96., 93.])

# %%
club_dict = {'Wolverhampton': 'Wolverhampton Wanderers', 'West': 'West Ham United', 'Brighton': 'Brighton & Hove Albion', 
             'Elche': np.nan, 'Leganés': np.nan, 'Le Puy Foot 43': np.nan}
fbr_data_df['Club'] = fbr_data_df['Club'].replace(club_dict)
fbr_data_df.dropna(subset=['Club'], inplace=True)

# %%
fbr_data_df['Nationality'] = fbr_data_df['Nationality'].map({'Republic': 'Ireland', 'Côte': "Côte d'Ivoire", 
                                'United': 'United States', 'Burkina': 'Burkina Faso',
                                'New': 'New Zealand', 'South': 'South Africa',
                                'Northern': 'Northern Ireland', 'br': 'Brazil',
                                'North': 'North Macedonia', 'Cape': 'Cape Verde',
                                'French': 'French Guiana', 'Central': 'Central African Republic',
                                'Costa': 'Costa Rica', 'Czech': 'Czech Republic',
                                'Equatorial': 'Equatorial Guinea'}).fillna(fbr_data_df['Nationality'])
fbr_data_df['Nationality'].unique()
# Out:
# array(['France', 'England', 'Brazil', 'Spain', 'Germany', 'Norway',
#        'Ukraine', 'Belgium', 'Poland', 'Italy', 'Japan', 'Ghana',
#        'Portugal', 'Egypt', 'Colombia', 'Argentina', 'Hungary', 'Uruguay',
#        'Scotland', 'Netherlands', 'Ireland', 'Switzerland', 'Jamaica',
#        'Sweden', 'Australia', 'Mali', 'Senegal', 'Wales', 'Romania',
#        'Slovakia', 'Cameroon', 'Denmark', 'Morocco', "Côte d'Ivoire",
#        'Turkey', 'Mexico', 'Greece', 'Ecuador', 'Albania', 'Paraguay',
#        'Gabon', 'Algeria', 'United States', 'Nigeria', 'Serbia',
#        'Burkina Faso', 'Congo', 'Iran', 'Grenada', 'Guinea-Bissau',
#        'New Zealand', 'Zimbabwe', 'South Africa', 'Togo', 'Kosovo',
#        'Chile', 'Northern Ireland', 'Guinea', 'North Macedonia',
#        'Cape Verde', 'Canada', 'Venezuela', 'Syria', 'Mozambique',
#        'Croatia', 'Austria', 'Slovenia', 'Montenegro', 'Russia',
#        'Suriname', 'Georgia', 'Tunisia', 'Haiti', 'French Guiana',
#        'Central African Republic', 'Angola', 'Costa Rica', 'Madagascar',
#        'Benin', 'Martinique', 'Iceland', 'Burundi', 'Malta',
#        'Czech Republic', 'Armenia', 'Korea Republic', 'Israel', 'Peru',
#        'Uzbekistan', 'Equatorial Guinea', 'Cyprus'], dtype=object)

# %%
fbr_data_df['Wage'] = fbr_data_df['Wage'].astype(str).str.replace(',', '')
fbr_data_df[fbr_data_df['Wage'].astype(str).str.contains(r'\D', na=False)]['Wage'].unique()
fbr_data_df['Wage'] = fbr_data_df['Wage'].replace('Weekly', np.nan)

# %%
fbr_data_df['Wage'] = (fbr_data_df['Wage'].astype(float)*52/1000000).round(2)
fbr_data_df
# Out:
#                 Player   Foot  Height  Weight              Birth Nationality  \
# 0       William Saliba  Right   193.0    76.0     March 24, 2001      France
# 1          Declan Rice  Right   185.0    77.0   January 14, 1999     England
# 2          Bukayo Saka   Left   178.0    64.0  September 5, 2001     England
# 3            Ben White  Right   182.0    73.0    October 8, 1997     England
# 4    Gabriel Magalhães   Left   190.0    78.0  December 19, 1997      Brazil
# ..                 ...    ...     ...     ...                ...         ...
# 408      Junior Sambia  Right   181.0    68.0  September 7, 1996      France
# 409      Shon Weissman  Right   174.0    73.0  February 14, 1996      Israel
# 410         Iron Gomis  Right   182.0    78.0   November 8, 1999      France
# 411    Emanuel Vignato  Right   175.0    68.0    August 24, 2000       Italy
# 412  Vincenzo Fiorillo   Left   190.0    74.0   January 13, 1990       Italy
#
#             Club   Wage  Expiration  Non-PenaltyGoals  ...  2023-2024  \
# 0        Arsenal  11.56      2027.0              0.05  ...        NaN
# 1        Arsenal  14.60      2028.0              0.15  ...        NaN
# 2        Arsenal  11.86      2027.0              0.33  ...        NaN
# 3        Arsenal   9.13      2028.0              0.05  ...        NaN
# 4        Arsenal   6.08      2027.0              0.09  ...        NaN
# ..           ...    ...         ...               ...  ...        ...
# 408  Salernitana   1.92      2026.0              0.00  ...        NaN
# 409  Salernitana   0.28      2024.0              0.19  ...        NaN
# 410  Salernitana   0.28      2024.0               NaN  ...        NaN
# 411  Salernitana   0.74      2024.0              0.00  ...        NaN
# 412  Salernitana   0.50      2025.0               NaN  ...        NaN
#
#      4Seasons*  2019-2020  2024-2025  2025-2026  5Seasons* 6Seasons*  \
# 0          NaN        NaN        NaN        NaN        NaN       NaN
# 1          NaN        NaN        NaN        NaN        NaN       NaN
# 2          NaN        NaN        NaN        NaN        NaN       NaN
# 3          NaN        NaN        NaN        NaN        NaN       NaN
# 4          NaN        NaN        NaN        NaN        NaN       NaN
# ..         ...        ...        ...        ...        ...       ...
# 408        NaN        NaN        NaN        NaN        NaN       NaN
# 409        NaN        NaN        NaN        NaN        NaN       NaN
# 410        NaN        NaN        NaN        NaN        NaN       NaN
# 411        NaN        NaN        NaN        NaN        NaN       NaN
# 412        NaN        NaN        NaN        NaN        NaN       NaN
#
#      3Seasons*  1Seasons*  2Seasons*
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2          NaN        NaN        NaN
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 408        NaN        NaN        NaN
# 409        NaN        NaN        NaN
# 410        NaN        NaN        NaN
# 411        NaN        NaN        NaN
# 412        NaN        NaN        NaN
#
# [1651 rows x 54 columns]

# %%
fbr_data_df['Expiration'] = fbr_data_df['Expiration'].astype(str).apply(lambda x: x[:-2] if x[-2]=='.' else x)
fbr_data_df['Expiration'].unique()
# Out:
# array(['2027', '2028', '2024', '202', '2026', '2025', 'nan', '2029',
#        '2030', '2031', '2032'], dtype=object)

# %%
fbr_data_df.isna().sum()
# Out:
# Player                           0
# Foot                            50
# Height                           0
# Weight                          13
# Birth                            0
# Nationality                      0
# Club                             0
# Wage                            51
# Expiration                       0
# Non-PenaltyGoals               381
# npxG:Non-PenaltyxG             381
# ShotsTotal                     381
# Assists                        381
# xAG:Exp.AssistedGoals          381
# npxG+xAG                       381
# Shot-CreatingActions           381
# PassesAttempted                381
# PassCompletion%                381
# ProgressivePasses              381
# ProgressiveCarries             381
# SuccessfulTake-Ons             381
# Touches(AttPen)                381
# ProgressivePassesRec           381
# Tackles                        381
# Interceptions                  381
# Blocks                         381
# Clearances                     381
# AerialsWon                     381
# PSxG-GA                       1533
# GoalsAgainst                  1533
# SavePercentage                1533
# PSxG/SoT                      1533
# Save%(PenaltyKicks)           1548
# CleanSheetPercentage          1533
# Touches                       1533
# Launch%                       1533
# GoalKicks                     1533
# Avg.LengthofGoalKicks         1533
# CrossesStopped%               1533
# Def.ActionsOutsidePen.Area    1533
# Avg.DistanceofDef.Actions     1533
# 2020-2021                     1651
# 2021-2022                     1651
# 2022-2023                     1651
# 2023-2024                     1651
# 4Seasons*                     1651
# 2019-2020                     1651
# 2024-2025                     1651
# 2025-2026                     1651
# 5Seasons*                     1651
# 6Seasons*                     1651
# 3Seasons*                     1651
# 1Seasons*                     1651
# 2Seasons*                     1651
# dtype: int64

# %%
fbr_data_df = fbr_data_df.drop(['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025', '2025-2026', 
                  '1Seasons*', '2Seasons*', '3Seasons*', '4Seasons*', '5Seasons*', '6Seasons*' ], axis=1)

fbr_data_df.isna().sum()
# Out:
# Player                           0
# Foot                            50
# Height                           0
# Weight                          13
# Birth                            0
# Nationality                      0
# Club                             0
# Wage                            51
# Expiration                       0
# Non-PenaltyGoals               381
# npxG:Non-PenaltyxG             381
# ShotsTotal                     381
# Assists                        381
# xAG:Exp.AssistedGoals          381
# npxG+xAG                       381
# Shot-CreatingActions           381
# PassesAttempted                381
# PassCompletion%                381
# ProgressivePasses              381
# ProgressiveCarries             381
# SuccessfulTake-Ons             381
# Touches(AttPen)                381
# ProgressivePassesRec           381
# Tackles                        381
# Interceptions                  381
# Blocks                         381
# Clearances                     381
# AerialsWon                     381
# PSxG-GA                       1533
# GoalsAgainst                  1533
# SavePercentage                1533
# PSxG/SoT                      1533
# Save%(PenaltyKicks)           1548
# CleanSheetPercentage          1533
# Touches                       1533
# Launch%                       1533
# GoalKicks                     1533
# Avg.LengthofGoalKicks         1533
# CrossesStopped%               1533
# Def.ActionsOutsidePen.Area    1533
# Avg.DistanceofDef.Actions     1533
# dtype: int64

# %%
merged_df = pd.merge(fbr_data_df, tm_data_df, on='Player')
merged_df
# Out:
#                  Player   Foot  Height  Weight            Birth_x Nationality  \
# 0        William Saliba  Right   193.0    76.0     March 24, 2001      France
# 1           Declan Rice  Right   185.0    77.0   January 14, 1999     England
# 2           Bukayo Saka   Left   178.0    64.0  September 5, 2001     England
# 3             Ben White  Right   182.0    73.0    October 8, 1997     England
# 4     Gabriel Magalhães   Left   190.0    78.0  December 19, 1997      Brazil
# ...                 ...    ...     ...     ...                ...         ...
# 1641      Junior Sambia  Right   181.0    68.0  September 7, 1996      France
# 1642      Shon Weissman  Right   174.0    73.0  February 14, 1996      Israel
# 1643         Iron Gomis  Right   182.0    78.0   November 8, 1999      France
# 1644    Emanuel Vignato  Right   175.0    68.0    August 24, 2000       Italy
# 1645  Vincenzo Fiorillo   Left   190.0    74.0   January 13, 1990       Italy
#
#              Club   Wage Expiration  Non-PenaltyGoals  ...  GoalKicks  \
# 0         Arsenal  11.56       2027              0.05  ...        NaN
# 1         Arsenal  14.60       2028              0.15  ...        NaN
# 2         Arsenal  11.86       2027              0.33  ...        NaN
# 3         Arsenal   9.13       2028              0.05  ...        NaN
# 4         Arsenal   6.08       2027              0.09  ...        NaN
# ...           ...    ...        ...               ...  ...        ...
# 1641  Salernitana   1.92       2026              0.00  ...        NaN
# 1642  Salernitana   0.28       2024              0.19  ...        NaN
# 1643  Salernitana   0.28       2024               NaN  ...        NaN
# 1644  Salernitana   0.74       2024              0.00  ...        NaN
# 1645  Salernitana   0.50       2025               NaN  ...        NaN
#
#       Avg.LengthofGoalKicks  CrossesStopped%  Def.ActionsOutsidePen.Area  \
# 0                       NaN              NaN                         NaN
# 1                       NaN              NaN                         NaN
# 2                       NaN              NaN                         NaN
# 3                       NaN              NaN                         NaN
# 4                       NaN              NaN                         NaN
# ...                     ...              ...                         ...
# 1641                    NaN              NaN                         NaN
# 1642                    NaN              NaN                         NaN
# 1643                    NaN              NaN                         NaN
# 1644                    NaN              NaN                         NaN
# 1645                    NaN              NaN                         NaN
#
#       Avg.DistanceofDef.Actions                Role                 Team  \
# 0                           NaN         Centre-Back           Arsenal FC
# 1                           NaN  Defensive Midfield           Arsenal FC
# 2                           NaN        Right Winger           Arsenal FC
# 3                           NaN          Right-Back           Arsenal FC
# 4                           NaN         Centre-Back           Arsenal FC
# ...                         ...                 ...                  ...
# 1641                        NaN          Right-Back  US Salernitana 1919
# 1642                        NaN      Centre-Forward  US Salernitana 1919
# 1643                        NaN  Attacking Midfield  US Salernitana 1919
# 1644                        NaN        Right Winger  US Salernitana 1919
# 1645                        NaN          Goalkeeper  US Salernitana 1919
#
#            Birth_y     Value                  League
# 0     Mar 24, 2001   €80.00m  English Premier League
# 1     Jan 14, 1999  €110.00m  English Premier League
# 2      Sep 5, 2001  €130.00m  English Premier League
# 3      Oct 8, 1997   €55.00m  English Premier League
# 4     Dec 19, 1997   €65.00m  English Premier League
# ...            ...       ...                     ...
# 1641   Sep 7, 1996    €2.50m         Italian Serie A
# 1642  Feb 14, 1996    €2.00m         Italian Serie A
# 1643   Nov 9, 1999    €1.00m         Italian Serie A
# 1644  Aug 24, 2000    €1.10m         Italian Serie A
# 1645  Jan 13, 1990     €200k         Italian Serie A
#
# [1646 rows x 46 columns]

# %%
merged_df = merged_df.drop(['Birth_x', 'Team'], axis=1)
merged_df.rename(columns={'Role_y':'Role', 'Birth_y':'Birth'}, inplace=True)
merged_df.columns
# Out:
# Index(['Player', 'Foot', 'Height', 'Weight', 'Nationality', 'Club', 'Wage',
#        'Expiration', 'Non-PenaltyGoals', 'npxG:Non-PenaltyxG', 'ShotsTotal',
#        'Assists', 'xAG:Exp.AssistedGoals', 'npxG+xAG', 'Shot-CreatingActions',
#        'PassesAttempted', 'PassCompletion%', 'ProgressivePasses',
#        'ProgressiveCarries', 'SuccessfulTake-Ons', 'Touches(AttPen)',
#        'ProgressivePassesRec', 'Tackles', 'Interceptions', 'Blocks',
#        'Clearances', 'AerialsWon', 'PSxG-GA', 'GoalsAgainst', 'SavePercentage',
#        'PSxG/SoT', 'Save%(PenaltyKicks)', 'CleanSheetPercentage', 'Touches',
#        'Launch%', 'GoalKicks', 'Avg.LengthofGoalKicks', 'CrossesStopped%',
#        'Def.ActionsOutsidePen.Area', 'Avg.DistanceofDef.Actions', 'Role',
#        'Birth', 'Value', 'League'],
#       dtype='object')

# %%
merged_df.isna().sum()
# Out:
# Player                           0
# Foot                            49
# Height                           0
# Weight                          13
# Nationality                      0
# Club                             0
# Wage                            50
# Expiration                       0
# Non-PenaltyGoals               381
# npxG:Non-PenaltyxG             381
# ShotsTotal                     381
# Assists                        381
# xAG:Exp.AssistedGoals          381
# npxG+xAG                       381
# Shot-CreatingActions           381
# PassesAttempted                381
# PassCompletion%                381
# ProgressivePasses              381
# ProgressiveCarries             381
# SuccessfulTake-Ons             381
# Touches(AttPen)                381
# ProgressivePassesRec           381
# Tackles                        381
# Interceptions                  381
# Blocks                         381
# Clearances                     381
# AerialsWon                     381
# PSxG-GA                       1528
# GoalsAgainst                  1528
# SavePercentage                1528
# PSxG/SoT                      1528
# Save%(PenaltyKicks)           1543
# CleanSheetPercentage          1528
# Touches                       1528
# Launch%                       1528
# GoalKicks                     1528
# Avg.LengthofGoalKicks         1528
# CrossesStopped%               1528
# Def.ActionsOutsidePen.Area    1528
# Avg.DistanceofDef.Actions     1528
# Role                             0
# Birth                            0
# Value                            0
# League                           0
# dtype: int64

# %%
merged_df['Birth'] = pd.to_datetime(merged_df['Birth'])
curr_date = pd.Timestamp.now()
merged_df['Age'] = merged_df['Birth'].apply(lambda x:relativedelta(curr_date, x).years)
merged_df.head()
# Out:
#               Player   Foot  Height  Weight Nationality     Club   Wage  \
# 0     William Saliba  Right   193.0    76.0      France  Arsenal  11.56
# 1        Declan Rice  Right   185.0    77.0     England  Arsenal  14.60
# 2        Bukayo Saka   Left   178.0    64.0     England  Arsenal  11.86
# 3          Ben White  Right   182.0    73.0     England  Arsenal   9.13
# 4  Gabriel Magalhães   Left   190.0    78.0      Brazil  Arsenal   6.08
#
#   Expiration  Non-PenaltyGoals  npxG:Non-PenaltyxG  ...  GoalKicks  \
# 0       2027              0.05                0.04  ...        NaN
# 1       2028              0.15                0.06  ...        NaN
# 2       2027              0.33                0.28  ...        NaN
# 3       2028              0.05                0.03  ...        NaN
# 4       2027              0.09                0.11  ...        NaN
#
#    Avg.LengthofGoalKicks  CrossesStopped%  Def.ActionsOutsidePen.Area  \
# 0                    NaN              NaN                         NaN
# 1                    NaN              NaN                         NaN
# 2                    NaN              NaN                         NaN
# 3                    NaN              NaN                         NaN
# 4                    NaN              NaN                         NaN
#
#    Avg.DistanceofDef.Actions                Role      Birth     Value  \
# 0                        NaN         Centre-Back 2001-03-24   €80.00m
# 1                        NaN  Defensive Midfield 1999-01-14  €110.00m
# 2                        NaN        Right Winger 2001-09-05  €130.00m
# 3                        NaN          Right-Back 1997-10-08   €55.00m
# 4                        NaN         Centre-Back 1997-12-19   €65.00m
#
#                    League  Age
# 0  English Premier League   23
# 1  English Premier League   25
# 2  English Premier League   22
# 3  English Premier League   26
# 4  English Premier League   26
#
# [5 rows x 45 columns]

# %%
merged_df['Value'].unique()
# Out:
# array(['€80.00m', '€110.00m', '€130.00m', '€55.00m', '€65.00m', '€35.00m',
#        '€60.00m', '€95.00m', '€42.00m', '€70.00m', '€38.00m', '€25.00m',
#        '€30.00m', '€15.00m', '€20.00m', '€2.00m', '€4.50m', '€75.00m',
#        '€32.00m', '€45.00m', '€13.00m', '€50.00m', '€18.00m', '€12.00m',
#        '€1.00m', '€600k', '€11.00m', '€90.00m', '€40.00m', '€180.00m',
#        '€9.00m', '€28.00m', '€10.00m', '€200k', '€16.00m', '€8.00m',
#        '€17.00m', '€1.50m', '€5.00m', '€2.20m', '€48.00m', '€85.00m',
#        '€2.50m', '€900k', '€300k', '€22.00m', '€250k', '€6.00m', '€700k',
#        '€3.50m', '€7.00m', '€4.00m', '€3.00m', '€500k', '€100k', '€800k',
#        '€2.80m', '€1.80m', '€400k', '€3.80m', '€14.00m', '€7.50m',
#        '€1.20m', '€1.40m', '€1.70m', '€1.60m', '€100.00m', '€150.00m',
#        '€24.00m', '€1.10m', '€150k', '€350k', '€5.50m', '€6.50m',
#        '€23.00m', '€1.30m', '€33.00m', '€450k', '€8.50m', '€9.50m',
#        '€2.70m', '€3.20m', '€75k', '€50k', '€4.80m', '€2.30m'],
#       dtype=object)

# %%
merged_df['Value'] = merged_df['Value'].apply(lambda x: x[1:-1] if x[-1]=='m' else float(x[1:-1])/1000).astype(float)

# %%
merged_df.head()
# Out:
#               Player   Foot  Height  Weight Nationality     Club   Wage  \
# 0     William Saliba  Right   193.0    76.0      France  Arsenal  11.56
# 1        Declan Rice  Right   185.0    77.0     England  Arsenal  14.60
# 2        Bukayo Saka   Left   178.0    64.0     England  Arsenal  11.86
# 3          Ben White  Right   182.0    73.0     England  Arsenal   9.13
# 4  Gabriel Magalhães   Left   190.0    78.0      Brazil  Arsenal   6.08
#
#   Expiration  Non-PenaltyGoals  npxG:Non-PenaltyxG  ...  GoalKicks  \
# 0       2027              0.05                0.04  ...        NaN
# 1       2028              0.15                0.06  ...        NaN
# 2       2027              0.33                0.28  ...        NaN
# 3       2028              0.05                0.03  ...        NaN
# 4       2027              0.09                0.11  ...        NaN
#
#    Avg.LengthofGoalKicks  CrossesStopped%  Def.ActionsOutsidePen.Area  \
# 0                    NaN              NaN                         NaN
# 1                    NaN              NaN                         NaN
# 2                    NaN              NaN                         NaN
# 3                    NaN              NaN                         NaN
# 4                    NaN              NaN                         NaN
#
#    Avg.DistanceofDef.Actions                Role      Birth  Value  \
# 0                        NaN         Centre-Back 2001-03-24   80.0
# 1                        NaN  Defensive Midfield 1999-01-14  110.0
# 2                        NaN        Right Winger 2001-09-05  130.0
# 3                        NaN          Right-Back 1997-10-08   55.0
# 4                        NaN         Centre-Back 1997-12-19   65.0
#
#                    League  Age
# 0  English Premier League   23
# 1  English Premier League   25
# 2  English Premier League   22
# 3  English Premier League   26
# 4  English Premier League   26
#
# [5 rows x 45 columns]

# %%
all_cols = ['Player', 'Position', 'Foot', 'Height', 'Weight', 'Nationality', 'Club', 
            'Wage', 'Expiration', 'Role', 'Team', 'Birth', 'Value']
gk_cols = ['PSxG-GA', 'GoalsAgainst', 'SavePercentage', 'PSxG/SoT', 'Save%(PenaltyKicks)', 'CleanSheetPercentage', 
           'Touches', 'Launch%', 'GoalKicks', 'Avg.LengthofGoalKicks', 'CrossesStopped%', 
           'Def.ActionsOutsidePen.Area', 'Avg.DistanceofDef.Actions']
mov_cols = ['Non-PenaltyGoals', 'npxG:Non-PenaltyxG',
       'ShotsTotal', 'Assists', 'xAG:Exp.AssistedGoals', 'npxG+xAG',
       'Shot-CreatingActions', 'PassesAttempted', 'PassCompletion%',
       'ProgressivePasses', 'ProgressiveCarries', 'SuccessfulTake-Ons',
       'Touches(AttPen)', 'ProgressivePassesRec', 'Tackles', 'Interceptions',
       'Blocks', 'Clearances', 'AerialsWon']

# %%
gk_df = merged_df[merged_df['Role']=='Goalkeeper']
gk_df
# Out:
#                  Player   Foot  Height  Weight Nationality         Club  Wage  \
# 5            David Raya  Right   186.0    81.0       Spain      Arsenal  5.17
# 16       Aaron Ramsdale  Right   195.0    79.0     England      Arsenal  7.30
# 26              Alisson  Right   193.0    91.0      Brazil    Liverpool  9.13
# 38    Caoimhín Kelleher  Right   188.0    81.0     Ireland    Liverpool  0.61
# 42               Adrián  Right   190.0    83.0       Spain    Liverpool  3.65
# ...                 ...    ...     ...     ...         ...          ...   ...
# 1630     Alessio Cragno  Right   184.0    78.0       Italy     Sassuolo  1.85
# 1634    Gianluca Pegolo   Left   183.0    76.0       Italy     Sassuolo  0.93
# 1636    Guillermo Ochoa  Right   183.0    78.0      Mexico  Salernitana  1.48
# 1640      Benoît Costil  Right   186.0    78.0      France  Salernitana  0.83
# 1645  Vincenzo Fiorillo   Left   190.0    74.0       Italy  Salernitana  0.50
#
#      Expiration  Non-PenaltyGoals  npxG:Non-PenaltyxG  ...  GoalKicks  \
# 5          2024               NaN                 NaN  ...       3.63
# 16         2026               NaN                 NaN  ...       3.85
# 26         2027               NaN                 NaN  ...       4.42
# 38         2026               NaN                 NaN  ...       3.16
# 42         2024               NaN                 NaN  ...        NaN
# ...         ...               ...                 ...  ...        ...
# 1630       2024               NaN                 NaN  ...        NaN
# 1634       2024               NaN                 NaN  ...        NaN
# 1636       2025               NaN                 NaN  ...       8.78
# 1640       2024               NaN                 NaN  ...       8.00
# 1645       2025               NaN                 NaN  ...        NaN
#
#       Avg.LengthofGoalKicks  CrossesStopped%  Def.ActionsOutsidePen.Area  \
# 5                      45.8             12.3                        1.53
# 16                     48.3             14.2                        0.92
# 26                     35.9              4.8                        1.94
# 38                     31.6              8.0                        1.26
# 42                      NaN              NaN                         NaN
# ...                     ...              ...                         ...
# 1630                    NaN              NaN                         NaN
# 1634                    NaN              NaN                         NaN
# 1636                   43.7              3.2                        0.52
# 1640                   51.8              0.5                        1.58
# 1645                    NaN              NaN                         NaN
#
#       Avg.DistanceofDef.Actions        Role      Birth  Value  \
# 5                          17.6  Goalkeeper 1995-09-15   35.0
# 16                         12.7  Goalkeeper 1998-05-14   25.0
# 26                         18.7  Goalkeeper 1992-10-02   32.0
# 38                         15.3  Goalkeeper 1998-11-23   18.0
# 42                          NaN  Goalkeeper 1987-01-03    0.6
# ...                         ...         ...        ...    ...
# 1630                        NaN  Goalkeeper 1994-06-28    2.5
# 1634                        NaN  Goalkeeper 1981-03-25    0.1
# 1636                       12.8  Goalkeeper 1985-07-13    1.5
# 1640                       19.1  Goalkeeper 1987-07-03    0.8
# 1645                        NaN  Goalkeeper 1990-01-13    0.2
#
#                       League  Age
# 5     English Premier League   28
# 16    English Premier League   25
# 26    English Premier League   31
# 38    English Premier League   25
# 42    English Premier League   37
# ...                      ...  ...
# 1630         Italian Serie A   29
# 1634         Italian Serie A   43
# 1636         Italian Serie A   38
# 1640         Italian Serie A   36
# 1645         Italian Serie A   34
#
# [226 rows x 45 columns]

# %%
gk_df = gk_df.drop(mov_cols, axis=1)

# %%
gk_df = gk_df[gk_df['GoalsAgainst'].notna()]

# %%
gk_df['Save%(PenaltyKicks)'].fillna(gk_df['Save%(PenaltyKicks)'].median(), inplace=True)

# %%
gk_df.isna().sum()
# Out:
# Player                        0
# Foot                          0
# Height                        0
# Weight                        0
# Nationality                   0
# Club                          0
# Wage                          0
# Expiration                    0
# PSxG-GA                       0
# GoalsAgainst                  0
# SavePercentage                0
# PSxG/SoT                      0
# Save%(PenaltyKicks)           0
# CleanSheetPercentage          0
# Touches                       0
# Launch%                       0
# GoalKicks                     0
# Avg.LengthofGoalKicks         0
# CrossesStopped%               0
# Def.ActionsOutsidePen.Area    0
# Avg.DistanceofDef.Actions     0
# Role                          0
# Birth                         0
# Value                         0
# League                        0
# Age                           0
# dtype: int64

# %%
gk_df.dtypes
# Out:
# Player                                object
# Foot                                  object
# Height                               float64
# Weight                               float64
# Nationality                           object
# Club                                  object
# Wage                                 float64
# Expiration                            object
# PSxG-GA                              float64
# GoalsAgainst                         float64
# SavePercentage                       float64
# PSxG/SoT                             float64
# Save%(PenaltyKicks)                  float64
# CleanSheetPercentage                 float64
# Touches                              float64
# Launch%                              float64
# GoalKicks                            float64
# Avg.LengthofGoalKicks                float64
# CrossesStopped%                      float64
# Def.ActionsOutsidePen.Area           float64
# Avg.DistanceofDef.Actions            float64
# Role                                  object
# Birth                         datetime64[ns]
# Value                                float64
# League                                object
# Age                                    int64
# dtype: object

# %% [markdown]
# ### Movement Players

# %%
df_mov = merged_df[merged_df['Role']!='Goalkeeper']
df_mov = df_mov.drop(gk_cols, axis=1)
df_mov
# Out:
#                  Player   Foot  Height  Weight Nationality         Club  \
# 0        William Saliba  Right   193.0    76.0      France      Arsenal
# 1           Declan Rice  Right   185.0    77.0     England      Arsenal
# 2           Bukayo Saka   Left   178.0    64.0     England      Arsenal
# 3             Ben White  Right   182.0    73.0     England      Arsenal
# 4     Gabriel Magalhães   Left   190.0    78.0      Brazil      Arsenal
# ...                 ...    ...     ...     ...         ...          ...
# 1639        Boulaye Dia  Right   180.0    74.0     Senegal  Salernitana
# 1641      Junior Sambia  Right   181.0    68.0      France  Salernitana
# 1642      Shon Weissman  Right   174.0    73.0      Israel  Salernitana
# 1643         Iron Gomis  Right   182.0    78.0      France  Salernitana
# 1644    Emanuel Vignato  Right   175.0    68.0       Italy  Salernitana
#
#        Wage Expiration  Non-PenaltyGoals  npxG:Non-PenaltyxG  ...  Tackles  \
# 0     11.56       2027              0.05                0.04  ...     1.00
# 1     14.60       2028              0.15                0.06  ...     1.94
# 2     11.86       2027              0.33                0.28  ...     2.05
# 3      9.13       2028              0.05                0.03  ...     1.26
# 4      6.08       2027              0.09                0.11  ...     1.16
# ...     ...        ...               ...                 ...  ...      ...
# 1639   2.56       2026              0.40                0.25  ...     0.34
# 1641   1.92       2026              0.00                0.05  ...     1.21
# 1642   0.28       2024              0.19                0.17  ...     0.96
# 1643   0.28       2024               NaN                 NaN  ...      NaN
# 1644   0.74       2024              0.00                0.13  ...     0.72
#
#       Interceptions  Blocks  Clearances  AerialsWon                Role  \
# 0              0.66    0.80        2.14        1.93         Centre-Back
# 1              1.31    1.12        1.44        1.10  Defensive Midfield
# 2              0.30    1.19        0.58        0.68        Right Winger
# 3              0.89    1.28        1.99        1.05          Right-Back
# 4              0.71    1.16        2.78        2.41         Centre-Back
# ...             ...     ...         ...         ...                 ...
# 1639           0.28    0.62        0.57        0.51      Centre-Forward
# 1641           1.21    0.73        2.19        2.67          Right-Back
# 1642           0.57    0.77        0.96        0.77      Centre-Forward
# 1643            NaN     NaN         NaN         NaN  Attacking Midfield
# 1644           0.18    1.26        0.90        0.00        Right Winger
#
#           Birth  Value                  League  Age
# 0    2001-03-24   80.0  English Premier League   23
# 1    1999-01-14  110.0  English Premier League   25
# 2    2001-09-05  130.0  English Premier League   22
# 3    1997-10-08   55.0  English Premier League   26
# 4    1997-12-19   65.0  English Premier League   26
# ...         ...    ...                     ...  ...
# 1639 1996-11-16   13.0         Italian Serie A   27
# 1641 1996-09-07    2.5         Italian Serie A   27
# 1642 1996-02-14    2.0         Italian Serie A   28
# 1643 1999-11-09    1.0         Italian Serie A   24
# 1644 2000-08-24    1.1         Italian Serie A   23
#
# [1420 rows x 32 columns]

# %%
df_mov = df_mov[df_mov['Non-PenaltyGoals'].notna()]

# %%
df_mov.isna().sum()
# Out:
# Player                   0
# Foot                     0
# Height                   0
# Weight                   0
# Nationality              0
# Club                     0
# Wage                     0
# Expiration               0
# Non-PenaltyGoals         0
# npxG:Non-PenaltyxG       0
# ShotsTotal               0
# Assists                  0
# xAG:Exp.AssistedGoals    0
# npxG+xAG                 0
# Shot-CreatingActions     0
# PassesAttempted          0
# PassCompletion%          0
# ProgressivePasses        0
# ProgressiveCarries       0
# SuccessfulTake-Ons       0
# Touches(AttPen)          0
# ProgressivePassesRec     0
# Tackles                  0
# Interceptions            0
# Blocks                   0
# Clearances               0
# AerialsWon               0
# Role                     0
# Birth                    0
# Value                    0
# League                   0
# Age                      0
# dtype: int64

# %%
df_mov.dtypes
# Out:
# Player                           object
# Foot                             object
# Height                          float64
# Weight                          float64
# Nationality                      object
# Club                             object
# Wage                            float64
# Expiration                       object
# Non-PenaltyGoals                float64
# npxG:Non-PenaltyxG              float64
# ShotsTotal                      float64
# Assists                         float64
# xAG:Exp.AssistedGoals           float64
# npxG+xAG                        float64
# Shot-CreatingActions            float64
# PassesAttempted                  object
# PassCompletion%                 float64
# ProgressivePasses               float64
# ProgressiveCarries              float64
# SuccessfulTake-Ons              float64
# Touches(AttPen)                 float64
# ProgressivePassesRec            float64
# Tackles                         float64
# Interceptions                   float64
# Blocks                          float64
# Clearances                      float64
# AerialsWon                      float64
# Role                             object
# Birth                    datetime64[ns]
# Value                           float64
# League                           object
# Age                               int64
# dtype: object

# %%
df_mov = df_mov.rename(columns={'Role': 'Position'})
defender_roles = ['Centre-Back', 'Left-Back', 'Right-Back']
midfield_roles = ['Defensive Midfield', 'Attacking Midfield', 'Central Midfield', 'Right Midfield','Left Midfield']
forward_roles = ['Right Winger', 'Left Winger', 'Centre-Forward', 'Second Striker']

# %%
role_map = {}
for role in defender_roles:
    role_map[role] = 'Defender'
for role in midfield_roles:
    role_map[role] = 'Midfielder'
for role in forward_roles:
    role_map[role] = 'Forward'
    
df_mov['Role'] = df_mov['Position'].map(role_map)

# %%
fifa_df = pd.read_csv('male_players.csv')
fifa_df = fifa_df.rename(columns={'Position': 'FIFA_Position'})
fifa_df = fifa_df.drop(['Unnamed: 0', 'Nation', 'Club',  'Age', 'URL', 'GK', 'Gender'], axis=1)

# %%
mov_fifa_df = df_mov.merge(fifa_df, left_on='Player', right_on='Name', how='left')
mov_fifa_df.drop(columns=['Name'], inplace=True)

# %%
gk_fifa_df = gk_df.merge(fifa_df, left_on='Player', right_on='Name', how='left')
gk_fifa_df.drop(columns=['Name'], inplace=True)

# %%
gk_df.to_csv('goalkeepers_df.csv', index=False)
df_mov.to_csv('players_df.csv', index=False)
gk_fifa_df.to_csv('goalkeepers_fifa_df.csv', index=False)
mov_fifa_df.to_csv('players_fifa_df.csv', index=False)
